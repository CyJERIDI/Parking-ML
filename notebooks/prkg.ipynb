# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %pip install prophet
import prophet
from sklearn.metrics import mean_squared_error, mean_absolute_error


df = pd.read_csv('/workspaces/codespaces-jupyter/data/verdun_MAJ.csv' )
 
df['y'] = pd.array(df.y, dtype=pd.Int64Dtype())
df['ds'] = pd.to_datetime(df.ds, format='%Y-%m-%d', errors='coerce')

df1 = df.loc[df.ds <"2020-01-01"].copy()
df2 =df.loc[df.ds> "2020-12-31"].copy()
frames = [df1, df2]
split_date = '2023-04-15'  
df = pd.concat(frames)
df_train = df.loc[df.ds <=split_date].copy()
df_test =df.loc[df.ds> split_date].copy()

from prophet import Prophet


def predict(date_future):
 df_train_prophet = df_train.reset_index()  

 

 model = Prophet ( )
 model.add_country_holidays(country_name='FR')

 model.fit(df_train_prophet)
 future_date = pd.date_range(date_future , periods=30, freq='D')
 future_date = pd.DataFrame({'ds': future_date })
 pred = model.predict(future_date )
 return pred
 predict('2023-05-01')
# Out:
# Collecting prophet
#   Downloading prophet-1.1.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 57.6 MB/s eta 0:00:00:00:0100:01
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.1.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from prophet) (1.24.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from prophet) (3.7.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from prophet) (1.5.3)
# Collecting LunarCalendar>=0.0.9 (from prophet)
#   Downloading LunarCalendar-0.0.9-py2.py3-none-any.whl (18 kB)
# Collecting convertdate>=2.1.2 (from prophet)
#   Downloading convertdate-2.4.0-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.9/47.9 kB 2.3 MB/s eta 0:00:00
# Collecting holidays>=0.14.2 (from prophet)
#   Downloading holidays-0.24-py3-none-any.whl (499 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.9/499.9 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in /home/codespace/.local/lib/python3.10/site-packages (from prophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/python/3.10.4/lib/python3.10/site-packages (from prophet) (4.64.0)
# Collecting pymeeus<=1,>=0.3.13 (from convertdate>=2.1.2->prophet)
#   Downloading PyMeeus-0.5.12.tar.gz (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 66.7 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... done
# Collecting hijri-converter (from holidays>=0.14.2->prophet)
#   Downloading hijri_converter-2.3.1-py3-none-any.whl (13 kB)
# Collecting korean-lunar-calendar (from holidays>=0.14.2->prophet)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Collecting ephem>=3.7.5.3 (from LunarCalendar>=0.0.9->prophet)
#   Downloading ephem-4.1.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 48.4 MB/s eta 0:00:00:00:01
# Requirement already satisfied: pytz in /home/codespace/.local/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->prophet) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.0->prophet) (1.16.0)
# Building wheels for collected packages: pymeeus
#   Building wheel for pymeeus (setup.py) ... done
#   Created wheel for pymeeus: filename=PyMeeus-0.5.12-py3-none-any.whl size=731999 sha256=2a5f4fbc3f676c4891a2a8baf9ff3a9e927e004f16b2810582c74ce5445b6a4f
#   Stored in directory: /home/codespace/.cache/pip/wheels/d6/67/78/aa2e8d108639dd23a5e9e72a4fc88bb44f5541894382712f48
# Successfully built pymeeus
# Installing collected packages: pymeeus, korean-lunar-calendar, ephem, hijri-converter, convertdate, LunarCalendar, holidays, cmdstanpy, prophet
#   WARNING: The script censusgeocode is installed in '/usr/local/python/3.10.4/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script lunar-find is installed in '/usr/local/python/3.10.4/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts install_cmdstan and install_cxx_toolchain are installed in '/usr/local/python/3.10.4/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed LunarCalendar-0.0.9 cmdstanpy-1.1.0 convertdate-2.4.0 ephem-4.1.4 hijri-converter-2.3.1 holidays-0.24 korean-lunar-calendar-0.3.1 prophet-1.1.2 pymeeus-0.5.12
#
# [notice] A new release of pip is available: 23.1.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
